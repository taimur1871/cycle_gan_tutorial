# %% [markdown]
# <a href="https://colab.research.google.com/github/taimur1871/cycle_gan_tutorial/blob/main/Rana_MLE_Perception_Engineer_Uber_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Today you are a MLE at Uber Perception Stack Team!**
# ## Your team is developing new software around automated detection of cars, pedestrians at all conditions for autonomous drive. One major bottleneck is data collection under severe weather conditions, especially capturing night-time images. So your task is to generate night time equivalent images from daytime images, such that you have access to some outdoor images acquired at night and some at day, but no pairwise images are available.
#
# ### *Pairwise image means*: same view available in Day and Night times.

# %% [markdown]
# In this assignment we implement CycleGAN using Keras with the intention to transform Day time to night time images for Autonomous Drive like in:
# https://github.com/simontomaskarlsson/CycleGAN-Keras
#
# This work is an adaptation of the blog in: https://machinelearningmastery.com/how-to-develop-cyclegan-models-from-scratch-with-keras/

# %% [markdown]
# #Lets start with the concepts of CycleGAN:
#
# The model architecture is comprised of two generator models: one generator (Generator-A) for generating images for the first domain (Domain-A) and the second generator (Generator-B) for generating images for the second domain (Domain-B). Lets consider here, **Domain-A: Daytime**, **Domain-B: Nighttime**
#
# * Generator-A -> Domain-A
# * Generator-B -> Domain-B
#
# The generator models perform image translation, meaning that the image generation process is conditional on an input image, specifically an image from the other domain. Generator-A takes an image from Domain-B as input and Generator-B takes an image from Domain-A as input.
#
# * Domain-B -> Generator-A -> Domain-A
# * Domain-A -> Generator-B -> Domain-B
# Each generator has a corresponding discriminator model.
#
# The first discriminator model (Discriminator-A) takes real images from Domain-A (daytime images) and generated images from Generator-A and predicts whether they are real or fake. The second discriminator model (Discriminator-B) takes real images from Domain-B (night-time images) and generated images from Generator-B and predicts whether they are real or fake.
#
# * Domain-A -> Discriminator-A -> [Real/Fake]
# * Domain-B -> Generator-A -> Discriminator-A -> [Real/Fake]
# * Domain-B -> Discriminator-B -> [Real/Fake]
# * Domain-A -> Generator-B -> Discriminator-B -> [Real/Fake]
# The discriminator and generator models are trained in an adversarial zero-sum process, like normal GAN models.
#
# The generators learn to better fool the discriminators and the discriminators learn to better detect fake images. Together, the models find an equilibrium during the training process.
#
# Passing an image through both generators is called a cycle. Together, each pair of generator models are trained to better reproduce the original source image, referred to as cycle consistency.
#
# * Domain-B -> Generator-A -> Domain-A -> Generator-B -> Domain-B
# * Domain-A -> Generator-B -> Domain-B -> Generator-A -> Domain-A
#
#
# **Our goal is to train such a 2 set Generator-Discriminator pair, to finally generate night-time images from day-time ones and quantify performance...**

# %% [markdown]
# # Task 0: Install libraries and load data

# %%
# !pip install -U tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading https://files.pythonhosted.org/packages/d6/98/8e97194e774f35a1319668e12571d5fa19f323e0ccae9d9890258aab1fcc/tensorflow_addons-0.12.0-cp36-cp36m-manylinux2010_x86_64.whl (703kB)
#      |████████████████████████████████| 706kB 8.0MB/s
# Requirement already satisfied, skipping upgrade: typeguard>=2.7 in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
#   Found existing installation: tensorflow-addons 0.8.3
#     Uninstalling tensorflow-addons-0.8.3:
#       Successfully uninstalled tensorflow-addons-0.8.3
# Successfully installed tensorflow-addons-0.12.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
import os
# The path below should point to the directory containing this notebook
# and the associated utility files
# Change it if necessary
os.chdir('/content/drive/MyDrive/4BAI/Week 9/training')
# !ls
# Out:
# day  discriminator_model_plot.png  generator_model_plot.png  night

# %% [markdown]
# ## **Task 1 [Instructor Led]:  Design functions for Generator-Discriminator pairs**:
#
#
# Step 1: Lets start by stepwise defining all libraries and functions needed to generate the model and pre-process the data

# %%
#Step 1: Defining a Patchgan discriminator model
import tensorflow_addons as tfa
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras import Model
from tensorflow.keras import Input
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.layers import BatchNormalization
from tensorflow_addons.layers import InstanceNormalization
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from random import randint

# %%
# define the discriminator model
def define_discriminator(image_shape):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# source image input
	in_image = Input(shape=image_shape)
	# C64
	d = Conv2D(64, (4,4), strides=(2,2), padding='same', 
            kernel_initializer=init)(in_image)
	d = LeakyReLU(alpha=0.2)(d) #Stride reduces shape of image
	# C128
	d = Conv2D(128, (4,4), padding='same', kernel_initializer=init)(d)
	d = InstanceNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# C256
	d = Conv2D(256, (4,4), padding='same', kernel_initializer=init)(d)
	d = InstanceNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# C512
	d = Conv2D(512, (4,4), padding='same', kernel_initializer=init)(d)
	d = InstanceNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# second last output layer
	d = Conv2D(512, (4,4), padding='same', kernel_initializer=init)(d)
	d = InstanceNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# patch output
	patch_out = Conv2D(1, (4,4), padding='same', kernel_initializer=init)(d)
	# define model
	model = Model(in_image, patch_out)
	# compile model
	model.compile(loss='mse', optimizer=Adam(lr=0.0002, beta_1=0.5),
               loss_weights=[0.5])
	return model

# %%
# Summarize and visualize model
# define image shape
image_shape = (256,256,3)
# create the model
model = define_discriminator(image_shape)
# summarize the model
model.summary()
# plot the model
plot_model(model, to_file='discriminator_model_plot.png',
           show_shapes=True,
           show_layer_names=True)
######### Note the final shape of the image patch=Patch size ############
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 128, 128, 64)      3136
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 128, 128, 128)     131200
# _________________________________________________________________
# instance_normalization_4 (In (None, 128, 128, 128)     256
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 128, 128, 128)     0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 128, 128, 256)     524544
# _________________________________________________________________
# instance_normalization_5 (In (None, 128, 128, 256)     512
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 128, 128, 256)     0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 128, 128, 512)     2097664
# _________________________________________________________________
# instance_normalization_6 (In (None, 128, 128, 512)     1024
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 128, 128, 512)     0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 128, 128, 512)     4194816
# _________________________________________________________________
# instance_normalization_7 (In (None, 128, 128, 512)     1024
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 128, 128, 512)     0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 128, 128, 1)       8193
# =================================================================
# Total params: 6,962,369
# Trainable params: 6,962,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Step 2: Generator Model
# generate a resnet block
def resnet_block(n_filters, input_layer):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# first layer convolutional layer
	g = Conv2D(n_filters, (3,3), padding='same', 
            kernel_initializer=init)(input_layer)
	g = InstanceNormalization()(g)
	g = Activation('relu')(g)
	# second convolutional layer
	g = Conv2D(n_filters, (3,3), padding='same', kernel_initializer=init)(g)
	g = InstanceNormalization()(g)
	# concatenate merge channel-wise with input layer
	g = Concatenate()([g, input_layer])
	return g

# %%
# define the standalone generator model
def define_generator(image_shape=(256,256,3), n_resnet=9):
	# weight initialization
  init = RandomNormal(stddev=0.02)
  # image input
  in_image = Input(shape=image_shape)
  # c7s1-64
  g = Conv2D(64, (7,7), padding='same', 
             kernel_initializer=init)(in_image)
  g=InstanceNormalization()(g)
  g = Activation('relu')(g)
  # d128
  g = Conv2D(128, (3,3), strides=(2,2), padding='same', 
             kernel_initializer=init)(g)
  g=InstanceNormalization()(g)
  g = Activation('relu')(g)
  # d256
  g = Conv2D(256, (3,3), strides=(2,2), padding='same',
             kernel_initializer=init)(g)
  g=InstanceNormalization()(g)
  g = Activation('relu')(g)
  # R256
  for _ in range(n_resnet):
    g = resnet_block(256, g)
  # u128
  g = Conv2DTranspose(128, (3,3), strides=(2,2), padding='same',
                      kernel_initializer=init)(g)
  g=InstanceNormalization()(g)
  g = Activation('relu')(g)
  # u64
  g = Conv2DTranspose(64, (3,3), strides=(2,2), padding='same',
                      kernel_initializer=init)(g)
  g=InstanceNormalization()(g)
  g = Activation('relu')(g)
  # c7s1-3
  g = Conv2D(3, (7,7), padding='same', 
             kernel_initializer=init)(g)
  g=InstanceNormalization()(g)
  out_image = Activation('sigmoid')(g)
  # define model
  model = Model(in_image, out_image)
  return model

# %%
# create the model
model = define_generator()
# summarize the model
model.summary()
# plot the model
plot_model(model, to_file='generator_model_plot.png', 
           show_shapes=True, 
           show_layer_names=True)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 256, 256, 64) 9472        input_3[0][0]
# __________________________________________________________________________________________________
# instance_normalization_8 (Insta (None, 256, 256, 64) 128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 64) 0           instance_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 128 73856       activation[0][0]
# __________________________________________________________________________________________________
# instance_normalization_9 (Insta (None, 128, 128, 128 256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 128 0           instance_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  295168      activation_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_10 (Inst (None, 64, 64, 256)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 256)  0           instance_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  590080      activation_2[0][0]
# __________________________________________________________________________________________________
# instance_normalization_11 (Inst (None, 64, 64, 256)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 256)  0           instance_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 256)  590080      activation_3[0][0]
# __________________________________________________________________________________________________
# instance_normalization_12 (Inst (None, 64, 64, 256)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 512)  0           instance_normalization_12[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# instance_normalization_13 (Inst (None, 64, 64, 256)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 256)  0           instance_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 256)  590080      activation_4[0][0]
# __________________________________________________________________________________________________
# instance_normalization_14 (Inst (None, 64, 64, 256)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 768)  0           instance_normalization_14[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 256)  1769728     concatenate_1[0][0]
# __________________________________________________________________________________________________
# instance_normalization_15 (Inst (None, 64, 64, 256)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 256)  0           instance_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 256)  590080      activation_5[0][0]
# __________________________________________________________________________________________________
# instance_normalization_16 (Inst (None, 64, 64, 256)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 1024) 0           instance_normalization_16[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 256)  2359552     concatenate_2[0][0]
# __________________________________________________________________________________________________
# instance_normalization_17 (Inst (None, 64, 64, 256)  512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 256)  0           instance_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 256)  590080      activation_6[0][0]
# __________________________________________________________________________________________________
# instance_normalization_18 (Inst (None, 64, 64, 256)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 1280) 0           instance_normalization_18[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 256)  2949376     concatenate_3[0][0]
# __________________________________________________________________________________________________
# instance_normalization_19 (Inst (None, 64, 64, 256)  512         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 256)  0           instance_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 256)  590080      activation_7[0][0]
# __________________________________________________________________________________________________
# instance_normalization_20 (Inst (None, 64, 64, 256)  512         conv2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 64, 1536) 0           instance_normalization_20[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 256)  3539200     concatenate_4[0][0]
# __________________________________________________________________________________________________
# instance_normalization_21 (Inst (None, 64, 64, 256)  512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 256)  0           instance_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 64, 256)  590080      activation_8[0][0]
# __________________________________________________________________________________________________
# instance_normalization_22 (Inst (None, 64, 64, 256)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 1792) 0           instance_normalization_22[0][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 256)  4129024     concatenate_5[0][0]
# __________________________________________________________________________________________________
# instance_normalization_23 (Inst (None, 64, 64, 256)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 256)  0           instance_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 64, 256)  590080      activation_9[0][0]
# __________________________________________________________________________________________________
# instance_normalization_24 (Inst (None, 64, 64, 256)  512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 2048) 0           instance_normalization_24[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 256)  4718848     concatenate_6[0][0]
# __________________________________________________________________________________________________
# instance_normalization_25 (Inst (None, 64, 64, 256)  512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 64, 256)  0           instance_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 64, 256)  590080      activation_10[0][0]
# __________________________________________________________________________________________________
# instance_normalization_26 (Inst (None, 64, 64, 256)  512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 64, 64, 2304) 0           instance_normalization_26[0][0]
#                                                                  concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 64, 256)  5308672     concatenate_7[0][0]
# __________________________________________________________________________________________________
# instance_normalization_27 (Inst (None, 64, 64, 256)  512         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 64, 256)  0           instance_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 256)  590080      activation_11[0][0]
# __________________________________________________________________________________________________
# instance_normalization_28 (Inst (None, 64, 64, 256)  512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 64, 64, 2560) 0           instance_normalization_28[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 128, 128, 128 2949248     concatenate_8[0][0]
# __________________________________________________________________________________________________
# instance_normalization_29 (Inst (None, 128, 128, 128 256         conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 128, 128, 128 0           instance_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 256, 256, 64) 73792       activation_12[0][0]
# __________________________________________________________________________________________________
# instance_normalization_30 (Inst (None, 256, 256, 64) 128         conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 256, 256, 64) 0           instance_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 256, 256, 3)  9411        activation_13[0][0]
# __________________________________________________________________________________________________
# instance_normalization_31 (Inst (None, 256, 256, 3)  6           conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 256, 256, 3)  0           instance_normalization_31[0][0]
# ==================================================================================================
# Total params: 35,276,553
# Trainable params: 35,276,553
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Step 3: Define a composite model for updating generators
# by adversarial and cycle loss
def define_composite_model(g_model_1,
                           d_model, 
                           g_model_2,
                           image_shape):
	# ensure the model we're updating is trainable
	g_model_1.trainable = True
	# mark discriminator as not trainable
	d_model.trainable = False
	# mark other generator model as not trainable
	g_model_2.trainable = False
	# discriminator element
	input_gen = Input(shape=image_shape)
	gen1_out = g_model_1(input_gen)
	output_d = d_model(gen1_out)
	# identity element
	input_id = Input(shape=image_shape)
	output_id = g_model_1(input_id)
	# forward cycle
	output_f = g_model_2(gen1_out)
	# backward cycle
	gen2_out = g_model_2(input_id)
	output_b = g_model_1(gen2_out)
	# define model graph
	model = Model([input_gen, input_id], 
               [output_d, output_id, output_f, output_b])
	# define optimization algorithm configuration
	opt = Adam(lr=0.0002, beta_1=0.5)
	# compile model with weighting of least squares loss and L1 loss
	model.compile(loss=['mse', 'mae', 'mae', 'mae'], 
               loss_weights=[1, 5, 10, 10], 
               optimizer=opt)
	return model
  ############ Notice no cross enytropy loss used here#################

# %%
#Step 4: All definitions together
# input shape
image_shape = (256,256,3)
# generator: A -> B
g_model_AtoB = define_generator(image_shape)
# generator: B -> A
g_model_BtoA = define_generator(image_shape)
# discriminator: A -> [real/fake]
d_model_A = define_discriminator(image_shape)
# discriminator: B -> [real/fake]
d_model_B = define_discriminator(image_shape)
# composite: A -> B -> [real/fake, A]
c_model_AtoB = define_composite_model(g_model_AtoB, d_model_B, 
                                      g_model_BtoA, image_shape)
# composite: B -> A -> [real/fake, B]
c_model_BtoA = define_composite_model(g_model_BtoA, d_model_A, 
                                      g_model_AtoB, image_shape)

# %%
#Step 5: Helper functions to select real samples and generate fake samples

# write a function to generate 'n_samples' 
# random integers in range (start,stop)
def randnums(start,stop,n_samples):
  ix=[]
  for i in range(n_samples):
    ix.append(randint(start,stop))
  ix=np.array(ix)
  return ix

# %%
# select a batch of random samples, returns images and target
def generate_real_samples(dataset, n_samples, patch_shape):
# choose random instances
  ix = randnums(0, dataset.shape[0]-1, n_samples)
  # retrieve selected images
  #print(ix,np.shape(dataset))
  X = dataset[ix]
  # generate 'real' class labels (1)
  y = np.ones((n_samples, patch_shape, patch_shape, 1))
  return X, y

# %%
# generate a batch of images, returns images and targets
def generate_fake_samples(g_model, dataset, patch_shape):
	# generate fake instance
	X = g_model.predict(dataset)
	# create 'fake' class labels (0)
	y = np.zeros((len(X), patch_shape, patch_shape, 1))
	return X, y

# %%
# update image pool for fake images
import random
def update_image_pool(pool, images, max_size=50):
  selected = list()
  for image in images:
    if len(pool) < max_size:
    # stock the pool
      pool.append(image)
      selected.append(image)
    elif random.random() < 0.5:
      # use image, but don't add it to the pool
      selected.append(image)
    else:
      # replace an existing image and use replaced image
      ix = randint(0, len(pool)-1)
      print(ix,np.shape(pool))
      selected.append(pool[ix])
      pool[ix] = image
  return np.asarray(selected)

# %% [markdown]
# # All helper functions are now defined, now lets begin training!
#
# Order of tasks:
# * Update Generator-B (A->B)
# * Update Discriminator-B
# * Update Generator-A (B->A)
# * Update Discriminator-A

# %%
# train function for the cyclegan models
def train(d_model_A, d_model_B, g_model_AtoB, g_model_BtoA,
          c_model_AtoB, c_model_BtoA, trainA,trainB):

  # define properties of the training run
  # Keep n_batch as 1 for per image training. n_epochs can be changed
  n_epochs, n_batch, = 10, 1
  # determine the output square shape of the discriminator
  # Notice n_patch depends on the discriminator output image size.
  # This parameter can be changed for improvement.
  n_patch = d_model_A.output_shape[1]
  #n_patch = 32
  
  # prepare image pool for fakes
  poolA, poolB = list(), list()
  # calculate the number of batches per training epoch
  bat_per_epo = int(len(trainA) / n_batch)
  # calculate the number of training iterations
  n_steps = bat_per_epo * n_epochs
  # manually enumerate epochs
  print(n_steps)
  for i in range(n_steps):
  # select a batch of real samples
    X_realA, y_realA = generate_real_samples(trainA, n_batch, n_patch)
    X_realB, y_realB = generate_real_samples(trainB, n_batch, n_patch)
    
    # generate a batch of fake samples
    X_fakeA, y_fakeA = generate_fake_samples(g_model_BtoA,
                                             X_realB, n_patch)
    X_fakeB, y_fakeB = generate_fake_samples(g_model_AtoB, 
                                             X_realA, n_patch)
    # update fakes from pool
    X_fakeA = update_image_pool(poolA, X_fakeA)
    X_fakeB = update_image_pool(poolB, X_fakeB)
    # update generator B->A via adversarial and cycle loss
    g_loss2, _, _, _, _ = c_model_BtoA.train_on_batch([X_realB, X_realA],
                                                      [y_realA, X_realA, 
                                                       X_realB, X_realA])
    # update discriminator for A -> [real/fake]
    dA_loss1 = d_model_A.train_on_batch(X_realA, y_realA)
    dA_loss2 = d_model_A.train_on_batch(X_fakeA, y_fakeA)
    # update generator A->B via adversarial and cycle loss
    g_loss1, _, _, _, _ = c_model_AtoB.train_on_batch([X_realA, X_realB], 
                                                      [y_realB, X_realB, 
                                                       X_realA, X_realB])
    # update discriminator for B -> [real/fake]
    dB_loss1 = d_model_B.train_on_batch(X_realB, y_realB)
    dB_loss2 = d_model_B.train_on_batch(X_fakeB, y_fakeB)
    # summarize performance
    print('>%d, dA[%.3f,%.3f] dB[%.3f,%.3f] g[%.3f,%.3f]' % 
          (i+1, dA_loss1,dA_loss2, dB_loss1,dB_loss2, g_loss1,g_loss2))
  return (g_model_AtoB, g_model_BtoA, c_model_AtoB, c_model_BtoA)

# %% [markdown]
# # **Task 2: Train the model from scratch**
# # Load the images DomainA-> Day, DomainB-> Night.
# You may use as many as 50 images to train the generator. More images will need more epochs and more train time. So limit training images to 30-50 images from each domain.
# # Call the train function to train on the images

# %%
import numpy as np

import matplotlib as mpl

import IPython.display as display
from PIL import Image

from tensorflow.keras.preprocessing import image
import cv2

# %%
# function to load images as np arrays
def load_img(img_path):
  im_temp = Image.open(img_path)
  im_temp = np.array(im_temp)
  im_temp = np.true_divide(im_temp, 255.0)
  im1 = cv2.resize(im_temp, (256,256))
  return im1

# %%
# load daytime images as trainA, 
# nighttime images as train B
# load as numpy array
############START CODE HERE#################################
trainA = np.array([load_img(os.path.join('day', i)) for
                   i in os.listdir('day')[:50]])
trainB = np.array([load_img(os.path.join('night', i)) for 
                   i in os.listdir('night')[:50]])
############################################################

# %% [markdown]
# # Next train the cycleGAN using the train function!

# %%
# train CycleGAN
############START CODE HERE##############################
# Call the function 
#train(d_model_A, d_model_B, g_model_AtoB, g_model_BtoA, 
        # c_model_AtoB, c_model_BtoA,trainA,trainB)
# and save the returned model
gen_a2b, gen_b2a, c_a2b, c_b2a = train(d_model_A, d_model_B,
                                       g_model_AtoB, g_model_BtoA,
                                       c_model_AtoB, c_model_BtoA,
                                       trainA, trainB)
########################################################
# Out:
# 500
# >1, dA[0.171,0.181] dB[0.037,0.040] g[8.051,6.317]
# >2, dA[0.284,0.190] dB[0.036,0.038] g[8.723,6.666]
# >3, dA[0.141,0.179] dB[0.201,0.337] g[3.213,2.933]
# >4, dA[0.309,0.175] dB[0.121,0.079] g[5.686,4.961]
# >5, dA[0.109,0.151] dB[0.225,0.117] g[4.361,4.088]
# >6, dA[0.098,0.092] dB[0.020,0.114] g[8.582,7.113]
# >7, dA[0.322,0.183] dB[0.008,0.082] g[4.901,4.809]
# >8, dA[0.145,0.210] dB[0.145,0.069] g[3.389,2.624]
# >9, dA[0.215,0.192] dB[0.008,0.031] g[6.719,5.708]
# >10, dA[0.139,0.201] dB[0.126,0.033] g[3.380,2.563]
# >11, dA[0.206,0.126] dB[0.037,0.026] g[6.098,5.145]
# >12, dA[0.119,0.148] dB[0.053,0.012] g[7.704,5.531]
# >13, dA[0.140,0.162] dB[0.039,0.043] g[7.944,5.844]
# >14, dA[0.141,0.108] dB[0.004,0.052] g[7.508,6.451]
# >15, dA[0.205,0.121] dB[0.077,0.039] g[6.756,5.202]
# >16, dA[0.099,0.168] dB[0.041,0.065] g[3.364,3.029]
# >17, dA[0.215,0.192] dB[0.453,0.179] g[3.991,3.447]
# >18, dA[0.122,0.160] dB[0.026,0.068] g[7.134,6.557]
# >19, dA[0.173,0.146] dB[0.032,0.018] g[7.181,5.421]
# >20, dA[0.213,0.179] dB[0.036,0.051] g[5.688,5.130]
# >21, dA[0.124,0.177] dB[0.097,0.100] g[3.541,3.411]
# >22, dA[0.110,0.121] dB[0.017,0.024] g[4.708,4.005]
# >23, dA[0.268,0.167] dB[0.036,0.009] g[4.812,4.293]
# >24, dA[0.111,0.157] dB[0.010,0.014] g[6.809,5.213]
# >25, dA[0.092,0.116] dB[0.033,0.039] g[8.202,6.756]
# >26, dA[0.317,0.158] dB[0.143,0.163] g[3.877,3.807]
# >27, dA[0.146,0.194] dB[0.014,0.054] g[6.946,5.194]
# >28, dA[0.142,0.150] dB[0.030,0.018] g[7.272,5.220]
# >29, dA[0.087,0.136] dB[0.010,0.018] g[8.197,6.659]
# >30, dA[0.202,0.144] dB[0.026,0.005] g[7.652,6.187]
# >31, dA[0.173,0.113] dB[0.024,0.013] g[7.699,6.006]
# >32, dA[0.067,0.174] dB[0.011,0.017] g[7.684,6.387]
# >33, dA[0.235,0.189] dB[0.016,0.007] g[7.691,5.684]
# >34, dA[0.150,0.174] dB[0.042,0.027] g[5.805,4.378]
# >35, dA[0.196,0.164] dB[0.011,0.020] g[7.271,5.915]
# >36, dA[0.168,0.144] dB[0.024,0.023] g[6.037,4.572]
# >37, dA[0.120,0.149] dB[0.064,0.015] g[7.042,5.095]
# >38, dA[0.263,0.130] dB[0.034,0.018] g[4.217,3.332]
# >39, dA[0.127,0.174] dB[0.017,0.018] g[6.456,4.979]
# >40, dA[0.097,0.128] dB[0.014,0.022] g[7.226,5.628]
# >41, dA[0.156,0.094] dB[0.022,0.013] g[6.381,5.206]
# >42, dA[0.162,0.129] dB[0.008,0.028] g[4.249,3.871]
# >43, dA[0.106,0.183] dB[0.159,0.066] g[4.175,3.182]
# >44, dA[0.105,0.078] dB[0.020,0.045] g[6.850,5.645]
# >45, dA[0.173,0.145] dB[0.024,0.016] g[7.092,6.084]
# >46, dA[0.028,0.185] dB[0.027,0.008] g[7.583,5.668]
# >47, dA[0.167,0.076] dB[0.178,0.098] g[3.441,3.037]
# >48, dA[0.288,0.173] dB[0.020,0.103] g[3.310,3.683]
# >49, dA[0.051,0.122] dB[0.023,0.009] g[7.255,5.669]
# >50, dA[0.354,0.161] dB[0.073,0.131] g[8.211,6.776]
# >51, dA[0.103,0.208] dB[0.071,0.043] g[7.268,5.183]
# 40 (50, 256, 256, 3)
# >52, dA[0.261,0.175] dB[0.220,0.217] g[7.619,6.118]
# >53, dA[0.138,0.136] dB[0.231,0.164] g[3.431,3.213]
# 9 (50, 256, 256, 3)
# 14 (50, 256, 256, 3)
# >54, dA[0.162,0.169] dB[0.046,0.046] g[3.777,3.440]
# 32 (50, 256, 256, 3)
# >55, dA[0.252,0.221] dB[0.148,0.068] g[3.816,3.612]
# >56, dA[0.124,0.169] dB[0.008,0.032] g[7.469,5.698]
# 9 (50, 256, 256, 3)
# >57, dA[0.209,0.104] dB[0.017,0.019] g[4.219,3.582]
# 36 (50, 256, 256, 3)
# >58, dA[0.170,0.161] dB[0.124,0.084] g[4.865,4.220]
# >59, dA[0.099,0.144] dB[0.018,0.028] g[4.713,3.752]
# 14 (50, 256, 256, 3)
# 1 (50, 256, 256, 3)
# >60, dA[0.234,0.167] dB[0.018,0.097] g[8.212,6.213]
# 12 (50, 256, 256, 3)
# 28 (50, 256, 256, 3)
# >61, dA[0.111,0.180] dB[0.100,0.056] g[6.864,5.065]
# 42 (50, 256, 256, 3)
# >62, dA[0.189,0.115] dB[0.044,0.073] g[6.308,5.209]
# 13 (50, 256, 256, 3)
# >63, dA[0.124,0.189] dB[0.162,0.105] g[4.150,4.046]
# 4 (50, 256, 256, 3)
# >64, dA[0.266,0.185] dB[0.009,0.023] g[8.123,6.640]
# 8 (50, 256, 256, 3)
# 48 (50, 256, 256, 3)
# >65, dA[0.186,0.172] dB[0.029,0.024] g[7.812,6.008]
# 45 (50, 256, 256, 3)
# 28 (50, 256, 256, 3)
# >66, dA[0.060,0.071] dB[0.025,0.016] g[5.022,4.572]
# 45 (50, 256, 256, 3)
# 22 (50, 256, 256, 3)
# >67, dA[0.071,0.117] dB[0.010,0.049] g[8.605,7.017]
# 37 (50, 256, 256, 3)
# 2 (50, 256, 256, 3)
# >68, dA[0.212,0.134] dB[0.024,0.014] g[4.044,3.691]
# 31 (50, 256, 256, 3)
# >69, dA[0.140,0.223] dB[0.089,0.149] g[3.564,3.189]
# 31 (50, 256, 256, 3)
# >70, dA[0.257,0.186] dB[0.021,0.007] g[4.404,3.812]
# 6 (50, 256, 256, 3)
# >71, dA[0.135,0.179] dB[0.018,0.011] g[7.946,5.539]
# 3 (50, 256, 256, 3)
# >72, dA[0.203,0.142] dB[0.009,0.015] g[7.022,5.507]
# 27 (50, 256, 256, 3)
# >73, dA[0.126,0.125] dB[0.003,0.023] g[6.230,4.910]
# 2 (50, 256, 256, 3)
# >74, dA[0.178,0.201] dB[0.019,0.055] g[7.122,5.459]
# 8 (50, 256, 256, 3)
# 36 (50, 256, 256, 3)
# >75, dA[0.040,0.120] dB[0.029,0.015] g[6.537,5.814]
# >76, dA[0.283,0.121] dB[0.032,0.023] g[3.866,3.582]
# 21 (50, 256, 256, 3)
# >77, dA[0.075,0.272] dB[0.015,0.032] g[5.689,4.969]
# 4 (50, 256, 256, 3)
# 24 (50, 256, 256, 3)
# >78, dA[0.145,0.204] dB[0.013,0.023] g[7.020,5.626]
# 29 (50, 256, 256, 3)
# 17 (50, 256, 256, 3)
# >79, dA[0.091,0.178] dB[0.023,0.028] g[6.389,4.956]
# 36 (50, 256, 256, 3)
# 26 (50, 256, 256, 3)
# >80, dA[0.250,0.186] dB[0.005,0.023] g[6.911,5.491]
# 25 (50, 256, 256, 3)
# >81, dA[0.192,0.103] dB[0.045,0.042] g[7.702,5.899]
# 15 (50, 256, 256, 3)
# >82, dA[0.176,0.190] dB[0.016,0.029] g[4.221,3.425]
# 40 (50, 256, 256, 3)
# 40 (50, 256, 256, 3)
# >83, dA[0.135,0.098] dB[0.243,0.136] g[3.787,3.466]
# 30 (50, 256, 256, 3)
# >84, dA[0.109,0.126] dB[0.027,0.075] g[4.319,3.739]
# 48 (50, 256, 256, 3)
# >85, dA[0.082,0.173] dB[0.022,0.019] g[7.044,5.386]
# 18 (50, 256, 256, 3)
# >86, dA[0.187,0.099] dB[0.161,0.120] g[3.202,2.845]
# 17 (50, 256, 256, 3)
# >87, dA[0.333,0.167] dB[0.003,0.025] g[6.930,6.143]
# 9 (50, 256, 256, 3)
# 12 (50, 256, 256, 3)
# >88, dA[0.084,0.161] dB[0.022,0.012] g[4.293,3.395]
# >89, dA[0.070,0.124] dB[0.105,0.080] g[5.289,4.824]
# 21 (50, 256, 256, 3)
# >90, dA[0.219,0.137] dB[0.025,0.009] g[3.837,3.290]
# >91, dA[0.150,0.167] dB[0.116,0.088] g[3.538,2.977]
# 40 (50, 256, 256, 3)
# >92, dA[0.128,0.190] dB[0.017,0.027] g[6.737,5.551]
# 31 (50, 256, 256, 3)
# >93, dA[0.071,0.069] dB[0.029,0.019] g[5.986,5.421]
# 26 (50, 256, 256, 3)
# >94, dA[0.303,0.225] dB[0.084,0.070] g[3.358,2.957]
# 44 (50, 256, 256, 3)
# >95, dA[0.213,0.256] dB[0.023,0.043] g[6.537,5.040]
# 30 (50, 256, 256, 3)
# 39 (50, 256, 256, 3)
# >96, dA[0.161,0.129] dB[0.026,0.054] g[2.765,2.751]
# 44 (50, 256, 256, 3)
# 12 (50, 256, 256, 3)
# >97, dA[0.155,0.173] dB[0.036,0.074] g[3.133,3.435]
# 46 (50, 256, 256, 3)
# 14 (50, 256, 256, 3)
# >98, dA[0.093,0.118] dB[0.004,0.041] g[4.213,4.244]
# 30 (50, 256, 256, 3)
# >99, dA[0.238,0.180] dB[0.083,0.044] g[3.343,3.276]
# 46 (50, 256, 256, 3)
# 9 (50, 256, 256, 3)
# >100, dA[0.116,0.128] dB[0.008,0.008] g[7.526,5.989]
# 12 (50, 256, 256, 3)
# >101, dA[0.211,0.216] dB[0.009,0.034] g[7.556,5.915]
# >102, dA[0.149,0.133] dB[0.191,0.289] g[3.835,2.878]
# 32 (50, 256, 256, 3)
# >103, dA[0.130,0.326] dB[0.038,0.050] g[4.717,4.333]
# 36 (50, 256, 256, 3)
# 35 (50, 256, 256, 3)
# >104, dA[0.392,0.169] dB[0.206,0.036] g[4.097,3.855]
# 22 (50, 256, 256, 3)
# >105, dA[0.156,0.216] dB[0.011,0.065] g[3.811,3.360]
# 1 (50, 256, 256, 3)
# >106, dA[0.196,0.179] dB[0.022,0.071] g[7.389,5.771]
# >107, dA[0.172,0.157] dB[0.034,0.056] g[4.515,3.564]
# 3 (50, 256, 256, 3)
# >108, dA[0.080,0.143] dB[0.129,0.139] g[3.125,2.895]
# 46 (50, 256, 256, 3)
# 42 (50, 256, 256, 3)
# >109, dA[0.168,0.155] dB[0.014,0.044] g[6.757,5.506]
# >110, dA[0.063,0.073] dB[0.015,0.058] g[4.612,4.039]
# 36 (50, 256, 256, 3)
# >111, dA[0.194,0.223] dB[0.018,0.026] g[7.405,5.605]
# 18 (50, 256, 256, 3)
# 1 (50, 256, 256, 3)
# >112, dA[0.161,0.189] dB[0.035,0.016] g[8.069,5.632]
# >113, dA[0.198,0.135] dB[0.006,0.020] g[4.360,3.790]
# 19 (50, 256, 256, 3)
# 37 (50, 256, 256, 3)
# >114, dA[0.065,0.115] dB[0.011,0.017] g[4.238,3.435]
# 11 (50, 256, 256, 3)
# >115, dA[0.157,0.126] dB[0.006,0.034] g[7.208,5.298]
# 35 (50, 256, 256, 3)
# 9 (50, 256, 256, 3)
# >116, dA[0.202,0.106] dB[0.036,0.043] g[7.297,5.649]
# 21 (50, 256, 256, 3)
# >117, dA[0.106,0.240] dB[0.278,0.348] g[3.855,3.367]
# 4 (50, 256, 256, 3)
# 22 (50, 256, 256, 3)
# >118, dA[0.121,0.117] dB[0.007,0.064] g[7.740,6.921]
# 35 (50, 256, 256, 3)
# >119, dA[0.076,0.166] dB[0.136,0.060] g[4.324,4.079]
# 14 (50, 256, 256, 3)
# 45 (50, 256, 256, 3)
# >120, dA[0.430,0.137] dB[0.103,0.079] g[3.524,3.594]
# >121, dA[0.085,0.293] dB[0.013,0.032] g[6.741,4.990]
# 11 (50, 256, 256, 3)
# >122, dA[0.169,0.230] dB[0.027,0.025] g[6.421,4.721]
# 20 (50, 256, 256, 3)
# >123, dA[0.202,0.207] dB[0.014,0.008] g[4.483,4.582]
# 21 (50, 256, 256, 3)
# 24 (50, 256, 256, 3)
# >124, dA[0.229,0.092] dB[0.013,0.022] g[4.439,3.988]
# >125, dA[0.144,0.175] dB[0.005,0.041] g[7.096,5.416]
# 38 (50, 256, 256, 3)
# >126, dA[0.124,0.090] dB[0.118,0.017] g[4.286,3.759]
# >127, dA[0.070,0.099] dB[0.084,0.086] g[3.344,3.033]
# 13 (50, 256, 256, 3)
# >128, dA[0.103,0.168] dB[0.068,0.087] g[3.301,3.135]
# 39 (50, 256, 256, 3)
# 33 (50, 256, 256, 3)
# >129, dA[0.299,0.122] dB[0.024,0.022] g[8.242,7.141]
# 8 (50, 256, 256, 3)
# 25 (50, 256, 256, 3)
# >130, dA[0.072,0.179] dB[0.010,0.011] g[6.791,4.737]
# 39 (50, 256, 256, 3)
# 2 (50, 256, 256, 3)
# >131, dA[0.123,0.129] dB[0.017,0.026] g[7.731,5.610]
# 32 (50, 256, 256, 3)
# >132, dA[0.255,0.126] dB[0.070,0.067] g[3.307,3.363]
# 43 (50, 256, 256, 3)
# >133, dA[0.090,0.085] dB[0.037,0.113] g[2.785,2.667]
# 21 (50, 256, 256, 3)
# >134, dA[0.208,0.176] dB[0.027,0.026] g[8.029,6.670]
# 16 (50, 256, 256, 3)
# >135, dA[0.072,0.108] dB[0.475,0.110] g[3.976,2.889]
# >136, dA[0.067,0.098] dB[0.057,0.167] g[3.461,3.445]
# 17 (50, 256, 256, 3)
# >137, dA[0.320,0.294] dB[0.154,0.039] g[4.769,4.678]
# >138, dA[0.120,0.119] dB[0.055,0.034] g[6.573,5.056]
# 37 (50, 256, 256, 3)
# >139, dA[0.234,0.122] dB[0.077,0.040] g[6.342,5.491]
# 8 (50, 256, 256, 3)
# 47 (50, 256, 256, 3)
# >140, dA[0.197,0.329] dB[0.008,0.015] g[5.290,4.696]
# 37 (50, 256, 256, 3)
# >141, dA[0.315,0.136] dB[0.005,0.012] g[6.471,5.193]
# 46 (50, 256, 256, 3)
# >142, dA[0.211,0.223] dB[0.099,0.061] g[3.087,2.872]
# 35 (50, 256, 256, 3)
# >143, dA[0.118,0.156] dB[0.035,0.075] g[6.622,5.296]
# 35 (50, 256, 256, 3)
# >144, dA[0.196,0.152] dB[0.041,0.189] g[6.529,5.091]
# >145, dA[0.129,0.158] dB[0.206,0.120] g[7.456,5.546]
# 44 (50, 256, 256, 3)
# >146, dA[0.266,0.135] dB[0.255,0.057] g[4.953,4.508]
# 43 (50, 256, 256, 3)
# >147, dA[0.135,0.300] dB[0.052,0.071] g[4.063,4.011]
# 38 (50, 256, 256, 3)
# 2 (50, 256, 256, 3)
# >148, dA[0.173,0.149] dB[0.026,0.034] g[4.028,3.260]
# >149, dA[0.164,0.148] dB[0.017,0.056] g[6.749,5.210]
# 44 (50, 256, 256, 3)
# >150, dA[0.149,0.157] dB[0.022,0.124] g[4.228,3.331]
# >151, dA[0.192,0.201] dB[0.039,0.488] g[8.210,6.397]
# 31 (50, 256, 256, 3)
# >152, dA[0.214,0.136] dB[0.166,0.535] g[3.459,2.965]
# 3 (50, 256, 256, 3)
# >153, dA[0.248,0.159] dB[0.089,0.104] g[4.168,4.196]
# 19 (50, 256, 256, 3)
# 26 (50, 256, 256, 3)
# >154, dA[0.150,0.244] dB[0.109,0.075] g[6.033,4.898]
# 37 (50, 256, 256, 3)
# 11 (50, 256, 256, 3)
# >155, dA[0.188,0.109] dB[0.186,0.110] g[3.111,2.702]
# 48 (50, 256, 256, 3)
# >156, dA[0.141,0.167] dB[0.100,0.064] g[4.233,4.698]
# 19 (50, 256, 256, 3)
# 1 (50, 256, 256, 3)
# >157, dA[0.234,0.254] dB[0.044,0.087] g[3.574,3.517]
# 1 (50, 256, 256, 3)
# >158, dA[0.126,0.130] dB[0.026,0.054] g[5.866,4.697]
# 49 (50, 256, 256, 3)
# 32 (50, 256, 256, 3)
# >159, dA[0.174,0.104] dB[0.110,0.044] g[7.133,5.144]
# 49 (50, 256, 256, 3)
# >160, dA[0.142,0.199] dB[0.050,0.036] g[7.644,5.606]
# >161, dA[0.221,0.183] dB[0.038,0.081] g[8.065,6.699]
# 9 (50, 256, 256, 3)
# 11 (50, 256, 256, 3)
# >162, dA[0.144,0.120] dB[0.011,0.027] g[7.307,5.723]
# 14 (50, 256, 256, 3)
# >163, dA[0.055,0.145] dB[0.046,0.038] g[5.776,5.215]
# >164, dA[0.282,0.114] dB[0.011,0.063] g[7.098,5.709]
# 22 (50, 256, 256, 3)
# >165, dA[0.253,0.176] dB[0.266,0.083] g[5.110,4.475]
# 34 (50, 256, 256, 3)
# 13 (50, 256, 256, 3)
# >166, dA[0.117,0.185] dB[0.028,0.118] g[6.900,5.697]
# 29 (50, 256, 256, 3)
# >167, dA[0.155,0.130] dB[0.011,0.075] g[6.905,5.595]
# >168, dA[0.135,0.128] dB[0.142,0.091] g[3.416,3.060]
# 24 (50, 256, 256, 3)
# 22 (50, 256, 256, 3)
# >169, dA[0.261,0.158] dB[0.178,0.047] g[3.922,3.875]
# 21 (50, 256, 256, 3)
# 24 (50, 256, 256, 3)
# >170, dA[0.073,0.096] dB[0.049,0.057] g[4.396,3.794]
# 11 (50, 256, 256, 3)
# >171, dA[0.209,0.193] dB[0.016,0.034] g[6.728,5.277]
# >172, dA[0.122,0.152] dB[0.021,0.039] g[6.093,4.695]
# >173, dA[0.089,0.112] dB[0.016,0.016] g[3.986,3.511]
# 25 (50, 256, 256, 3)
# >174, dA[0.182,0.180] dB[0.140,0.083] g[3.962,3.682]
# 29 (50, 256, 256, 3)
# 29 (50, 256, 256, 3)
# >175, dA[0.180,0.127] dB[0.005,0.027] g[6.062,4.857]
# >176, dA[0.062,0.105] dB[0.018,0.025] g[7.752,5.473]
# >177, dA[0.073,0.105] dB[0.120,0.081] g[3.399,2.661]
# 12 (50, 256, 256, 3)
# >178, dA[0.175,0.170] dB[0.032,0.017] g[6.772,5.491]
# 46 (50, 256, 256, 3)
# >179, dA[0.104,0.075] dB[0.099,0.072] g[3.337,2.757]
# 37 (50, 256, 256, 3)
# >180, dA[0.247,0.155] dB[0.032,0.038] g[3.920,3.236]
# >181, dA[0.032,0.138] dB[0.105,0.031] g[6.459,4.840]
# >182, dA[0.250,0.216] dB[0.077,0.164] g[3.131,2.760]
# 36 (50, 256, 256, 3)
# 19 (50, 256, 256, 3)
# >183, dA[0.206,0.141] dB[0.090,0.035] g[5.405,4.475]
# 29 (50, 256, 256, 3)
# 27 (50, 256, 256, 3)
# >184, dA[0.141,0.123] dB[0.067,0.143] g[3.133,2.645]
# 37 (50, 256, 256, 3)
# >185, dA[0.098,0.149] dB[0.045,0.073] g[2.897,2.409]
# 32 (50, 256, 256, 3)
# >186, dA[0.225,0.196] dB[0.014,0.037] g[3.888,3.026]
# 38 (50, 256, 256, 3)
# >187, dA[0.138,0.142] dB[0.020,0.037] g[6.934,5.093]
# 34 (50, 256, 256, 3)
# >188, dA[0.112,0.123] dB[0.084,0.098] g[3.771,3.865]
# 44 (50, 256, 256, 3)
# >189, dA[0.175,0.149] dB[0.022,0.019] g[5.976,4.886]
# 6 (50, 256, 256, 3)
# >190, dA[0.196,0.191] dB[0.088,0.057] g[3.171,2.552]
# 14 (50, 256, 256, 3)
# >191, dA[0.090,0.096] dB[0.037,0.030] g[6.765,5.328]
# >192, dA[0.131,0.119] dB[0.198,0.088] g[4.404,3.892]
# 37 (50, 256, 256, 3)
# 33 (50, 256, 256, 3)
# >193, dA[0.156,0.147] dB[0.016,0.065] g[7.468,5.452]
# 37 (50, 256, 256, 3)
# >194, dA[0.128,0.179] dB[0.035,0.010] g[6.216,4.448]
# 30 (50, 256, 256, 3)
# >195, dA[0.111,0.099] dB[0.139,0.127] g[3.636,3.217]
# 46 (50, 256, 256, 3)
# 9 (50, 256, 256, 3)
# >196, dA[0.140,0.107] dB[0.012,0.022] g[4.573,3.892]
# 14 (50, 256, 256, 3)
# >197, dA[0.067,0.160] dB[0.028,0.012] g[7.219,6.064]
# 5 (50, 256, 256, 3)
# >198, dA[0.129,0.108] dB[0.009,0.075] g[7.444,6.169]
# 44 (50, 256, 256, 3)
# >199, dA[0.270,0.165] dB[0.075,0.039] g[7.243,5.254]
# 30 (50, 256, 256, 3)
# >200, dA[0.136,0.193] dB[0.010,0.054] g[3.896,3.028]
# >201, dA[0.074,0.126] dB[0.059,0.037] g[4.747,4.500]
# 16 (50, 256, 256, 3)
# >202, dA[0.152,0.149] dB[0.027,0.028] g[7.529,5.956]
# >203, dA[0.153,0.329] dB[0.014,0.018] g[7.007,5.842]
# 48 (50, 256, 256, 3)
# >204, dA[0.369,0.233] dB[0.016,0.010] g[8.212,6.642]
# 25 (50, 256, 256, 3)
# 46 (50, 256, 256, 3)
# >205, dA[0.283,0.149] dB[0.021,0.008] g[6.567,5.459]
# 13 (50, 256, 256, 3)
# >206, dA[0.194,0.146] dB[0.093,0.048] g[4.064,3.216]
# 4 (50, 256, 256, 3)
# >207, dA[0.165,0.267] dB[0.021,0.022] g[6.534,4.857]
# 4 (50, 256, 256, 3)
# >208, dA[0.157,0.174] dB[0.038,0.057] g[7.236,5.772]
# 39 (50, 256, 256, 3)
# >209, dA[0.253,0.180] dB[0.024,0.011] g[7.177,5.294]
# >210, dA[0.160,0.182] dB[0.082,0.087] g[3.556,3.073]
# 11 (50, 256, 256, 3)
# >211, dA[0.127,0.206] dB[0.006,0.012] g[5.086,4.202]
# 19 (50, 256, 256, 3)
# >212, dA[0.174,0.109] dB[0.013,0.009] g[6.272,4.790]
# >213, dA[0.142,0.133] dB[0.004,0.008] g[6.975,5.070]
# 39 (50, 256, 256, 3)
# 24 (50, 256, 256, 3)
# >214, dA[0.132,0.114] dB[0.007,0.010] g[3.924,3.330]
# >215, dA[0.108,0.099] dB[0.048,0.083] g[4.196,3.400]
# >216, dA[0.308,0.235] dB[0.007,0.023] g[7.434,5.860]
# 2 (50, 256, 256, 3)
# >217, dA[0.168,0.123] dB[0.034,0.048] g[7.953,5.974]
# 8 (50, 256, 256, 3)
# >218, dA[0.100,0.180] dB[0.016,0.058] g[6.839,5.448]
# 29 (50, 256, 256, 3)
# 45 (50, 256, 256, 3)
# >219, dA[0.108,0.172] dB[0.068,0.040] g[4.372,3.754]
# 5 (50, 256, 256, 3)
# >220, dA[0.338,0.203] dB[0.044,0.010] g[6.324,5.267]
# 34 (50, 256, 256, 3)
# >221, dA[0.208,0.144] dB[0.057,0.025] g[5.291,4.331]
# 43 (50, 256, 256, 3)
# >222, dA[0.175,0.158] dB[0.101,0.022] g[6.009,4.320]
# 9 (50, 256, 256, 3)
# 10 (50, 256, 256, 3)
# >223, dA[0.240,0.156] dB[0.087,0.026] g[7.138,5.862]
# >224, dA[0.157,0.202] dB[0.049,0.072] g[3.387,3.033]
# >225, dA[0.178,0.156] dB[0.020,0.022] g[4.905,4.136]
# 16 (50, 256, 256, 3)
# >226, dA[0.182,0.154] dB[0.023,0.019] g[7.275,5.423]
# 49 (50, 256, 256, 3)
# 19 (50, 256, 256, 3)
# >227, dA[0.159,0.165] dB[0.006,0.012] g[7.095,5.032]
# 10 (50, 256, 256, 3)
# >228, dA[0.152,0.209] dB[0.004,0.006] g[7.326,5.790]
# >229, dA[0.152,0.120] dB[0.018,0.038] g[4.683,4.065]
# 17 (50, 256, 256, 3)
# >230, dA[0.193,0.102] dB[0.035,0.006] g[7.145,5.003]
# 23 (50, 256, 256, 3)
# >231, dA[0.088,0.112] dB[0.088,0.084] g[3.824,3.176]
# 20 (50, 256, 256, 3)
# >232, dA[0.191,0.135] dB[0.027,0.018] g[3.348,2.620]
# 19 (50, 256, 256, 3)
# >233, dA[0.100,0.177] dB[0.003,0.018] g[7.435,5.311]
# 23 (50, 256, 256, 3)
# 34 (50, 256, 256, 3)
# >234, dA[0.182,0.143] dB[0.031,0.015] g[6.757,4.899]
# 33 (50, 256, 256, 3)
# >235, dA[0.172,0.192] dB[0.006,0.022] g[6.581,4.715]
# >236, dA[0.125,0.104] dB[0.005,0.060] g[7.421,5.767]
# >237, dA[0.110,0.136] dB[0.008,0.009] g[7.677,5.754]
# >238, dA[0.263,0.176] dB[0.005,0.013] g[8.099,6.564]
# 20 (50, 256, 256, 3)
# >239, dA[0.250,0.221] dB[0.010,0.017] g[7.498,6.014]
# 48 (50, 256, 256, 3)
# >240, dA[0.087,0.221] dB[0.039,0.034] g[4.254,3.344]
# 28 (50, 256, 256, 3)
# >241, dA[0.159,0.111] dB[0.041,0.046] g[7.645,6.008]
# 37 (50, 256, 256, 3)
# >242, dA[0.187,0.227] dB[0.032,0.017] g[5.674,5.376]
# >243, dA[0.232,0.121] dB[0.200,0.145] g[4.508,4.083]
# 33 (50, 256, 256, 3)
# >244, dA[0.156,0.194] dB[0.009,0.062] g[7.543,5.916]
# 26 (50, 256, 256, 3)
# >245, dA[0.124,0.172] dB[0.065,0.015] g[7.408,5.754]
# 13 (50, 256, 256, 3)
# 33 (50, 256, 256, 3)
# >246, dA[0.223,0.220] dB[0.019,0.049] g[7.396,6.104]
# 33 (50, 256, 256, 3)
# >247, dA[0.145,0.137] dB[0.079,0.035] g[3.500,2.757]
# 25 (50, 256, 256, 3)
# >248, dA[0.231,0.153] dB[0.015,0.021] g[6.342,5.569]
# >249, dA[0.096,0.147] dB[0.027,0.014] g[6.821,5.014]
# 34 (50, 256, 256, 3)
# >250, dA[0.173,0.120] dB[0.005,0.007] g[6.408,4.691]
# 27 (50, 256, 256, 3)
# 13 (50, 256, 256, 3)
# >251, dA[0.073,0.094] dB[0.026,0.045] g[7.371,5.463]
# 16 (50, 256, 256, 3)
# >252, dA[0.173,0.210] dB[0.011,0.012] g[6.738,5.826]
# 41 (50, 256, 256, 3)
# >253, dA[0.129,0.102] dB[0.060,0.084] g[7.697,5.975]
# 26 (50, 256, 256, 3)
# >254, dA[0.169,0.189] dB[0.030,0.134] g[4.558,3.457]
# 29 (50, 256, 256, 3)
# >255, dA[0.190,0.150] dB[0.167,0.010] g[8.545,6.382]
# 2 (50, 256, 256, 3)
# >256, dA[0.121,0.170] dB[0.048,0.021] g[6.256,4.619]
# 14 (50, 256, 256, 3)
# 41 (50, 256, 256, 3)
# >257, dA[0.163,0.131] dB[0.009,0.016] g[4.147,3.672]
# 17 (50, 256, 256, 3)
# >258, dA[0.153,0.116] dB[0.015,0.017] g[7.003,5.230]
# 2 (50, 256, 256, 3)
# 46 (50, 256, 256, 3)
# >259, dA[0.124,0.184] dB[0.011,0.007] g[7.767,5.866]
# 14 (50, 256, 256, 3)
# >260, dA[0.112,0.140] dB[0.020,0.021] g[6.165,4.994]
# 32 (50, 256, 256, 3)
# >261, dA[0.213,0.126] dB[0.024,0.011] g[7.201,5.534]
# >262, dA[0.132,0.153] dB[0.039,0.136] g[3.147,2.646]
# 32 (50, 256, 256, 3)
# >263, dA[0.079,0.097] dB[0.038,0.014] g[7.138,5.711]
# 17 (50, 256, 256, 3)
# >264, dA[0.094,0.117] dB[0.029,0.051] g[6.972,5.535]
# 41 (50, 256, 256, 3)
# >265, dA[0.225,0.067] dB[0.060,0.043] g[3.707,3.274]
# 31 (50, 256, 256, 3)
# 28 (50, 256, 256, 3)
# >266, dA[0.118,0.128] dB[0.082,0.047] g[3.479,2.880]
# 18 (50, 256, 256, 3)
# 1 (50, 256, 256, 3)
# >267, dA[0.141,0.380] dB[0.006,0.070] g[4.931,4.157]
# 31 (50, 256, 256, 3)
# 4 (50, 256, 256, 3)
# >268, dA[0.223,0.171] dB[0.057,0.034] g[3.587,2.903]
# 22 (50, 256, 256, 3)
# 43 (50, 256, 256, 3)
# >269, dA[0.266,0.194] dB[0.069,0.039] g[7.308,6.159]
# 25 (50, 256, 256, 3)
# >270, dA[0.180,0.245] dB[0.018,0.013] g[7.472,5.953]
# 31 (50, 256, 256, 3)
# 29 (50, 256, 256, 3)
# >271, dA[0.210,0.130] dB[0.023,0.014] g[7.078,5.818]
# 12 (50, 256, 256, 3)
# >272, dA[0.149,0.144] dB[0.002,0.052] g[7.311,5.965]
# 23 (50, 256, 256, 3)
# >273, dA[0.107,0.155] dB[0.011,0.046] g[6.859,5.161]
# 23 (50, 256, 256, 3)
# >274, dA[0.077,0.095] dB[0.105,0.258] g[3.211,2.939]
# 24 (50, 256, 256, 3)
# >275, dA[0.251,0.141] dB[0.051,0.050] g[3.542,3.752]
# 37 (50, 256, 256, 3)
# 42 (50, 256, 256, 3)
# >276, dA[0.041,0.129] dB[0.021,0.057] g[8.062,5.697]
# >277, dA[0.149,0.113] dB[0.045,0.035] g[6.950,5.138]
# 11 (50, 256, 256, 3)
# >278, dA[0.119,0.040] dB[0.009,0.053] g[6.944,5.313]
# >279, dA[0.093,0.304] dB[0.022,0.076] g[7.844,6.016]
# 0 (50, 256, 256, 3)
# 9 (50, 256, 256, 3)
# >280, dA[0.262,0.147] dB[0.006,0.024] g[7.007,5.029]
# 49 (50, 256, 256, 3)
# >281, dA[0.268,0.170] dB[0.005,0.059] g[5.859,5.247]
# 40 (50, 256, 256, 3)
# 29 (50, 256, 256, 3)
# >282, dA[0.108,0.140] dB[0.004,0.014] g[7.577,5.467]
# >283, dA[0.106,0.132] dB[0.039,0.072] g[5.001,3.902]
# 49 (50, 256, 256, 3)
# 41 (50, 256, 256, 3)
# >284, dA[0.183,0.136] dB[0.058,0.018] g[5.918,4.987]
# 17 (50, 256, 256, 3)
# >285, dA[0.074,0.107] dB[0.044,0.004] g[5.668,5.113]
# 35 (50, 256, 256, 3)
# >286, dA[0.260,0.142] dB[0.040,0.047] g[6.338,5.570]
# >287, dA[0.159,0.212] dB[0.257,0.118] g[3.192,2.899]
# 40 (50, 256, 256, 3)
# >288, dA[0.159,0.142] dB[0.054,0.070] g[6.971,6.039]
# 27 (50, 256, 256, 3)
# >289, dA[0.124,0.145] dB[0.068,0.085] g[3.359,3.351]
# 21 (50, 256, 256, 3)
# >290, dA[0.119,0.100] dB[0.021,0.024] g[6.986,5.588]
# 45 (50, 256, 256, 3)
# >291, dA[0.069,0.190] dB[0.009,0.005] g[6.875,5.792]
# >292, dA[0.273,0.181] dB[0.018,0.031] g[7.942,6.411]
# 35 (50, 256, 256, 3)
# >293, dA[0.087,0.116] dB[0.046,0.013] g[7.214,5.576]
# >294, dA[0.301,0.107] dB[0.010,0.018] g[8.565,6.845]
# 40 (50, 256, 256, 3)
# 29 (50, 256, 256, 3)
# >295, dA[0.126,0.138] dB[0.023,0.010] g[7.308,6.236]
# 33 (50, 256, 256, 3)
# >296, dA[0.059,0.081] dB[0.018,0.048] g[6.547,5.702]
# >297, dA[0.108,0.244] dB[0.310,0.192] g[4.021,3.533]
# >298, dA[0.107,0.150] dB[0.026,0.039] g[7.086,6.300]
# 1 (50, 256, 256, 3)
# >299, dA[0.337,0.074] dB[0.021,0.083] g[4.272,3.793]
# 16 (50, 256, 256, 3)
# >300, dA[0.074,0.272] dB[0.174,0.066] g[3.835,3.551]
# >301, dA[0.185,0.254] dB[0.016,0.062] g[4.826,4.844]
# 24 (50, 256, 256, 3)
# >302, dA[0.196,0.043] dB[0.019,0.018] g[4.718,4.448]
# 4 (50, 256, 256, 3)
# >303, dA[0.170,0.196] dB[0.023,0.010] g[4.173,3.693]
# 17 (50, 256, 256, 3)
# >304, dA[0.045,0.247] dB[0.007,0.021] g[4.793,3.953]
# 32 (50, 256, 256, 3)
# >305, dA[0.286,0.097] dB[0.005,0.013] g[4.666,4.151]
# >306, dA[0.131,0.205] dB[0.203,0.213] g[3.498,2.830]
# 39 (50, 256, 256, 3)
# >307, dA[0.126,0.157] dB[0.210,0.261] g[3.229,2.795]
# 38 (50, 256, 256, 3)
# >308, dA[0.162,0.151] dB[0.178,0.054] g[3.299,3.411]
# >309, dA[0.060,0.149] dB[0.031,0.145] g[3.994,4.421]
# >310, dA[0.252,0.113] dB[0.061,0.022] g[7.042,5.782]
# >311, dA[0.075,0.134] dB[0.073,0.020] g[6.260,4.858]
# 44 (50, 256, 256, 3)
# >312, dA[0.335,0.164] dB[0.221,0.048] g[7.393,6.121]
# 45 (50, 256, 256, 3)
# >313, dA[0.206,0.192] dB[0.096,0.051] g[6.542,5.355]
# 43 (50, 256, 256, 3)
# 11 (50, 256, 256, 3)
# >314, dA[0.100,0.124] dB[0.091,0.050] g[7.681,5.642]
# 15 (50, 256, 256, 3)
# >315, dA[0.097,0.128] dB[0.181,0.102] g[3.008,2.725]
# >316, dA[0.270,0.189] dB[0.024,0.118] g[4.983,4.982]
# >317, dA[0.163,0.245] dB[0.053,0.006] g[4.031,3.041]
# 40 (50, 256, 256, 3)
# 9 (50, 256, 256, 3)
# >318, dA[0.203,0.094] dB[0.016,0.005] g[8.162,6.861]
# 49 (50, 256, 256, 3)
# >319, dA[0.176,0.182] dB[0.007,0.025] g[7.474,5.936]
# >320, dA[0.086,0.220] dB[0.160,0.120] g[3.950,3.833]
# >321, dA[0.194,0.194] dB[0.008,0.032] g[7.542,5.823]
# 12 (50, 256, 256, 3)
# >322, dA[0.134,0.168] dB[0.072,0.030] g[7.828,6.636]
# 30 (50, 256, 256, 3)
# >323, dA[0.303,0.301] dB[0.020,0.031] g[4.794,3.959]
# 22 (50, 256, 256, 3)
# >324, dA[0.240,0.138] dB[0.032,0.022] g[3.589,3.012]
# >325, dA[0.147,0.186] dB[0.005,0.024] g[6.994,5.673]
# >326, dA[0.184,0.149] dB[0.091,0.058] g[3.943,3.411]
# >327, dA[0.093,0.151] dB[0.041,0.048] g[7.206,5.767]
# 27 (50, 256, 256, 3)
# >328, dA[0.160,0.182] dB[0.061,0.065] g[5.526,4.372]
# >329, dA[0.053,0.111] dB[0.146,0.244] g[4.144,4.046]
# >330, dA[0.114,0.124] dB[0.030,0.039] g[4.737,4.610]
# >331, dA[0.219,0.166] dB[0.025,0.037] g[7.811,5.647]
# 0 (50, 256, 256, 3)
# >332, dA[0.210,0.190] dB[0.014,0.029] g[4.459,3.844]
# 26 (50, 256, 256, 3)
# >333, dA[0.141,0.155] dB[0.006,0.044] g[7.543,5.690]
# >334, dA[0.115,0.151] dB[0.023,0.022] g[7.399,6.448]
# >335, dA[0.098,0.146] dB[0.091,0.095] g[4.662,4.309]
# >336, dA[0.262,0.182] dB[0.011,0.037] g[7.309,6.038]
# >337, dA[0.169,0.147] dB[0.014,0.014] g[4.027,3.577]
# 46 (50, 256, 256, 3)
# >338, dA[0.141,0.099] dB[0.003,0.011] g[7.594,5.453]
# 49 (50, 256, 256, 3)
# >339, dA[0.212,0.217] dB[0.004,0.007] g[7.687,5.860]
# 33 (50, 256, 256, 3)
# 0 (50, 256, 256, 3)
# >340, dA[0.134,0.153] dB[0.015,0.082] g[4.925,4.025]
# 3 (50, 256, 256, 3)
# 8 (50, 256, 256, 3)
# >341, dA[0.150,0.088] dB[0.038,0.014] g[7.656,5.394]
# 45 (50, 256, 256, 3)
# >342, dA[0.115,0.157] dB[0.040,0.026] g[5.056,4.688]
# 6 (50, 256, 256, 3)
# >343, dA[0.160,0.132] dB[0.006,0.031] g[6.851,5.501]
# 34 (50, 256, 256, 3)
# >344, dA[0.123,0.151] dB[0.112,0.065] g[3.704,2.751]
# >345, dA[0.098,0.254] dB[0.003,0.029] g[4.864,3.908]
# >346, dA[0.216,0.221] dB[0.029,0.024] g[7.255,5.332]
# 40 (50, 256, 256, 3)
# >347, dA[0.130,0.178] dB[0.005,0.019] g[7.005,5.045]
# >348, dA[0.211,0.094] dB[0.023,0.014] g[6.556,5.224]
# 36 (50, 256, 256, 3)
# >349, dA[0.127,0.141] dB[0.274,0.262] g[4.131,4.011]
# 1 (50, 256, 256, 3)
# 32 (50, 256, 256, 3)
# >350, dA[0.073,0.096] dB[0.049,0.027] g[5.103,4.081]
# 2 (50, 256, 256, 3)
# >351, dA[0.273,0.168] dB[0.014,0.010] g[7.156,5.437]
# >352, dA[0.100,0.133] dB[0.016,0.042] g[7.351,5.534]
# >353, dA[0.281,0.229] dB[0.007,0.013] g[7.242,5.963]
# 1 (50, 256, 256, 3)
# >354, dA[0.125,0.192] dB[0.006,0.010] g[6.840,5.004]
# >355, dA[0.211,0.174] dB[0.013,0.033] g[7.099,5.716]
# >356, dA[0.170,0.119] dB[0.010,0.009] g[6.306,4.866]
# 15 (50, 256, 256, 3)
# >357, dA[0.180,0.105] dB[0.015,0.009] g[7.998,6.026]
# 25 (50, 256, 256, 3)
# >358, dA[0.034,0.151] dB[0.007,0.009] g[7.211,5.351]
# 46 (50, 256, 256, 3)
# >359, dA[0.138,0.050] dB[0.003,0.011] g[4.775,3.787]
# >360, dA[0.078,0.179] dB[0.013,0.003] g[6.860,5.121]
# 34 (50, 256, 256, 3)
# >361, dA[0.268,0.125] dB[0.010,0.010] g[7.677,5.932]
# >362, dA[0.168,0.167] dB[0.003,0.013] g[4.929,4.168]
# 5 (50, 256, 256, 3)
# 4 (50, 256, 256, 3)
# >363, dA[0.224,0.121] dB[0.009,0.012] g[6.638,5.537]
# 19 (50, 256, 256, 3)
# >364, dA[0.065,0.142] dB[0.099,0.129] g[3.395,2.922]
# 44 (50, 256, 256, 3)
# >365, dA[0.265,0.141] dB[0.024,0.037] g[3.522,3.941]
# 39 (50, 256, 256, 3)
# >366, dA[0.085,0.181] dB[0.035,0.010] g[6.568,5.061]
# 2 (50, 256, 256, 3)
# >367, dA[0.184,0.132] dB[0.015,0.037] g[7.849,5.262]
# 38 (50, 256, 256, 3)
# >368, dA[0.136,0.124] dB[0.011,0.012] g[6.572,5.172]
# 7 (50, 256, 256, 3)
# >369, dA[0.253,0.135] dB[0.088,0.097] g[3.736,3.722]
# >370, dA[0.048,0.201] dB[0.048,0.020] g[3.381,2.671]
# >371, dA[0.182,0.244] dB[0.005,0.010] g[5.236,4.342]
# 8 (50, 256, 256, 3)
# >372, dA[0.261,0.159] dB[0.006,0.009] g[6.768,5.520]
# 25 (50, 256, 256, 3)
# 47 (50, 256, 256, 3)
# >373, dA[0.181,0.188] dB[0.008,0.010] g[4.969,4.265]
# 17 (50, 256, 256, 3)
# 2 (50, 256, 256, 3)
# >374, dA[0.124,0.135] dB[0.009,0.007] g[6.985,6.176]
# >375, dA[0.161,0.150] dB[0.016,0.013] g[3.673,2.798]
# 12 (50, 256, 256, 3)
# >376, dA[0.142,0.140] dB[0.008,0.006] g[3.824,3.094]
# 7 (50, 256, 256, 3)
# 6 (50, 256, 256, 3)
# >377, dA[0.122,0.144] dB[0.010,0.006] g[4.998,4.331]
# 12 (50, 256, 256, 3)
# >378, dA[0.208,0.161] dB[0.001,0.015] g[5.143,4.816]
# 27 (50, 256, 256, 3)
# >379, dA[0.124,0.126] dB[0.063,0.089] g[3.426,3.283]
# >380, dA[0.106,0.153] dB[0.002,0.008] g[7.635,6.035]
# 24 (50, 256, 256, 3)
# 29 (50, 256, 256, 3)
# >381, dA[0.147,0.176] dB[0.260,0.342] g[3.051,2.724]
# 24 (50, 256, 256, 3)
# 24 (50, 256, 256, 3)
# >382, dA[0.107,0.116] dB[0.104,0.111] g[3.261,3.035]
# 36 (50, 256, 256, 3)
# 6 (50, 256, 256, 3)
# >383, dA[0.148,0.070] dB[0.133,0.058] g[3.084,2.636]
# 25 (50, 256, 256, 3)
# >384, dA[0.142,0.235] dB[0.018,0.131] g[6.690,5.410]
# >385, dA[0.118,0.201] dB[0.037,0.011] g[6.916,5.340]
# 12 (50, 256, 256, 3)
# 8 (50, 256, 256, 3)
# >386, dA[0.216,0.054] dB[0.219,0.113] g[3.363,3.063]
# 1 (50, 256, 256, 3)
# 6 (50, 256, 256, 3)
# >387, dA[0.165,0.149] dB[0.026,0.084] g[2.700,2.885]
# >388, dA[0.191,0.245] dB[0.083,0.168] g[2.645,2.492]
# 4 (50, 256, 256, 3)
# 47 (50, 256, 256, 3)
# >389, dA[0.095,0.086] dB[0.003,0.110] g[6.944,5.194]
# 25 (50, 256, 256, 3)
# 39 (50, 256, 256, 3)
# >390, dA[0.205,0.178] dB[0.073,0.020] g[7.231,5.716]
# >391, dA[0.211,0.160] dB[0.016,0.039] g[5.346,4.786]
# >392, dA[0.153,0.151] dB[0.016,0.026] g[4.959,4.035]
# 22 (50, 256, 256, 3)
# >393, dA[0.069,0.072] dB[0.017,0.027] g[7.601,5.449]
# >394, dA[0.077,0.113] dB[0.012,0.009] g[5.076,4.168]
# >395, dA[0.084,0.111] dB[0.018,0.005] g[7.358,5.349]
# 1 (50, 256, 256, 3)
# >396, dA[0.097,0.098] dB[0.006,0.019] g[7.601,5.760]
# 14 (50, 256, 256, 3)
# 42 (50, 256, 256, 3)
# >397, dA[0.083,0.081] dB[0.011,0.028] g[6.514,4.945]
# 43 (50, 256, 256, 3)
# >398, dA[0.105,0.127] dB[0.031,0.029] g[4.152,3.677]
# >399, dA[0.357,0.166] dB[0.160,0.110] g[3.944,4.182]
# 46 (50, 256, 256, 3)
# >400, dA[0.095,0.142] dB[0.017,0.041] g[3.576,3.377]
# >401, dA[0.146,0.164] dB[0.018,0.008] g[6.898,5.507]
# 31 (50, 256, 256, 3)
# >402, dA[0.019,0.091] dB[0.011,0.003] g[4.258,3.438]
# 7 (50, 256, 256, 3)
# >403, dA[0.308,0.175] dB[0.005,0.006] g[7.340,5.877]
# 10 (50, 256, 256, 3)
# >404, dA[0.027,0.053] dB[0.008,0.016] g[4.856,4.050]
# 39 (50, 256, 256, 3)
# >405, dA[0.057,0.104] dB[0.004,0.007] g[6.764,4.871]
# 32 (50, 256, 256, 3)
# >406, dA[0.205,0.059] dB[0.014,0.010] g[7.901,6.401]
# 6 (50, 256, 256, 3)
# >407, dA[0.056,0.121] dB[0.007,0.022] g[7.289,5.462]
# >408, dA[0.015,0.292] dB[0.009,0.008] g[6.965,4.875]
# 25 (50, 256, 256, 3)
# >409, dA[0.432,0.055] dB[0.013,0.009] g[7.635,6.189]
# 15 (50, 256, 256, 3)
# 14 (50, 256, 256, 3)
# >410, dA[0.250,0.175] dB[0.005,0.016] g[7.403,5.825]
# 29 (50, 256, 256, 3)
# 12 (50, 256, 256, 3)
# >411, dA[0.128,0.241] dB[0.030,0.012] g[5.065,3.613]
# >412, dA[0.146,0.249] dB[0.006,0.019] g[7.196,5.707]
# 2 (50, 256, 256, 3)
# 10 (50, 256, 256, 3)
# >413, dA[0.276,0.255] dB[0.009,0.006] g[7.716,6.386]
# 0 (50, 256, 256, 3)
# >414, dA[0.150,0.113] dB[0.012,0.018] g[7.416,5.728]
# 44 (50, 256, 256, 3)
# >415, dA[0.171,0.125] dB[0.006,0.003] g[6.175,4.840]
# 13 (50, 256, 256, 3)
# 33 (50, 256, 256, 3)
# >416, dA[0.115,0.132] dB[0.014,0.012] g[6.273,4.844]
# 12 (50, 256, 256, 3)
# >417, dA[0.086,0.211] dB[0.016,0.015] g[7.697,5.754]
# >418, dA[0.157,0.180] dB[0.003,0.005] g[4.687,3.633]
# 15 (50, 256, 256, 3)
# >419, dA[0.162,0.115] dB[0.011,0.005] g[3.802,3.035]
# >420, dA[0.172,0.151] dB[0.002,0.007] g[7.545,5.803]
# >421, dA[0.174,0.161] dB[0.004,0.005] g[7.030,5.256]
# 45 (50, 256, 256, 3)
# >422, dA[0.106,0.097] dB[0.002,0.008] g[5.641,4.987]
# 14 (50, 256, 256, 3)
# >423, dA[0.177,0.159] dB[0.005,0.003] g[6.400,4.867]
# 20 (50, 256, 256, 3)
# >424, dA[0.212,0.200] dB[0.172,0.085] g[3.068,2.497]
# 12 (50, 256, 256, 3)
# >425, dA[0.126,0.145] dB[0.020,0.058] g[6.412,5.127]
# 15 (50, 256, 256, 3)
# 9 (50, 256, 256, 3)
# >426, dA[0.127,0.153] dB[0.021,0.025] g[8.084,6.116]
# 0 (50, 256, 256, 3)
# >427, dA[0.151,0.143] dB[0.017,0.006] g[6.855,5.135]
# 21 (50, 256, 256, 3)
# >428, dA[0.181,0.130] dB[0.008,0.028] g[6.921,5.438]
# >429, dA[0.187,0.206] dB[0.004,0.030] g[7.386,6.062]
# >430, dA[0.140,0.159] dB[0.011,0.072] g[6.920,5.108]
# >431, dA[0.099,0.133] dB[0.004,0.041] g[4.454,3.581]
# 1 (50, 256, 256, 3)
# 18 (50, 256, 256, 3)
# >432, dA[0.115,0.110] dB[0.159,0.068] g[3.778,3.362]
# 34 (50, 256, 256, 3)
# >433, dA[0.127,0.115] dB[0.054,0.292] g[4.454,3.948]
# 19 (50, 256, 256, 3)
# >434, dA[0.031,0.078] dB[0.064,0.050] g[7.412,5.031]
# 12 (50, 256, 256, 3)
# >435, dA[0.127,0.162] dB[0.048,0.036] g[4.986,4.526]
# 4 (50, 256, 256, 3)
# >436, dA[0.197,0.165] dB[0.040,0.014] g[6.831,5.638]
# 42 (50, 256, 256, 3)
# 11 (50, 256, 256, 3)
# >437, dA[0.168,0.039] dB[0.120,0.067] g[3.649,3.133]
# 22 (50, 256, 256, 3)
# >438, dA[0.076,0.178] dB[0.042,0.093] g[6.514,5.418]
# 23 (50, 256, 256, 3)
# >439, dA[0.123,0.201] dB[0.111,0.122] g[4.167,3.198]
# 1 (50, 256, 256, 3)
# >440, dA[0.229,0.087] dB[0.045,0.036] g[5.478,4.723]
# 32 (50, 256, 256, 3)
# >441, dA[0.130,0.217] dB[0.074,0.045] g[8.141,6.691]
# 14 (50, 256, 256, 3)
# >442, dA[0.158,0.110] dB[0.012,0.016] g[5.989,4.885]
# 13 (50, 256, 256, 3)
# >443, dA[0.129,0.225] dB[0.013,0.013] g[4.611,3.483]
# >444, dA[0.199,0.220] dB[0.014,0.007] g[3.777,2.916]
# 18 (50, 256, 256, 3)
# 37 (50, 256, 256, 3)
# >445, dA[0.178,0.030] dB[0.006,0.007] g[6.149,4.977]
# >446, dA[0.120,0.225] dB[0.010,0.011] g[5.923,4.782]
# >447, dA[0.216,0.157] dB[0.015,0.028] g[7.522,6.158]
# 30 (50, 256, 256, 3)
# 37 (50, 256, 256, 3)
# >448, dA[0.070,0.073] dB[0.022,0.004] g[3.702,2.992]
# 21 (50, 256, 256, 3)
# 26 (50, 256, 256, 3)
# >449, dA[0.183,0.098] dB[0.005,0.021] g[3.999,3.503]
# >450, dA[0.072,0.143] dB[0.135,0.075] g[3.355,3.023]
# >451, dA[0.171,0.150] dB[0.007,0.038] g[6.782,5.541]
# 48 (50, 256, 256, 3)
# >452, dA[0.216,0.143] dB[0.056,0.027] g[3.012,3.029]
# 45 (50, 256, 256, 3)
# >453, dA[0.219,0.111] dB[0.051,0.023] g[3.750,3.612]
# 42 (50, 256, 256, 3)
# 27 (50, 256, 256, 3)
# >454, dA[0.125,0.234] dB[0.015,0.014] g[7.204,6.205]
# 10 (50, 256, 256, 3)
# >455, dA[0.119,0.203] dB[0.055,0.060] g[3.856,3.970]
# 6 (50, 256, 256, 3)
# 48 (50, 256, 256, 3)
# >456, dA[0.107,0.113] dB[0.007,0.020] g[8.051,6.428]
# 14 (50, 256, 256, 3)
# 1 (50, 256, 256, 3)
# >457, dA[0.119,0.194] dB[0.005,0.035] g[5.331,4.201]
# 29 (50, 256, 256, 3)
# >458, dA[0.113,0.084] dB[0.105,0.049] g[4.721,3.586]
# 36 (50, 256, 256, 3)
# 2 (50, 256, 256, 3)
# >459, dA[0.104,0.076] dB[0.030,0.127] g[7.450,5.305]
# 30 (50, 256, 256, 3)
# >460, dA[0.088,0.156] dB[0.121,0.018] g[7.001,5.868]
# 13 (50, 256, 256, 3)
# 22 (50, 256, 256, 3)
# >461, dA[0.202,0.106] dB[0.024,0.046] g[6.372,4.937]
# 29 (50, 256, 256, 3)
# >462, dA[0.050,0.114] dB[0.030,0.010] g[6.915,4.871]
# 1 (50, 256, 256, 3)
# >463, dA[0.272,0.261] dB[0.010,0.008] g[7.663,5.875]
# 46 (50, 256, 256, 3)
# 27 (50, 256, 256, 3)
# >464, dA[0.213,0.125] dB[0.003,0.010] g[5.429,4.834]
# 43 (50, 256, 256, 3)
# >465, dA[0.069,0.124] dB[0.006,0.016] g[6.512,4.900]
# 15 (50, 256, 256, 3)
# >466, dA[0.073,0.124] dB[0.127,0.074] g[4.238,3.984]
# 32 (50, 256, 256, 3)
# >467, dA[0.129,0.119] dB[0.025,0.041] g[3.479,3.634]
# 45 (50, 256, 256, 3)
# >468, dA[0.181,0.158] dB[0.021,0.015] g[3.013,2.777]
# >469, dA[0.177,0.244] dB[0.011,0.022] g[7.440,5.975]
# >470, dA[0.203,0.113] dB[0.024,0.009] g[4.288,3.701]
# 45 (50, 256, 256, 3)
# >471, dA[0.240,0.145] dB[0.016,0.033] g[6.715,5.857]
# 23 (50, 256, 256, 3)
# 3 (50, 256, 256, 3)
# >472, dA[0.128,0.136] dB[0.022,0.012] g[3.975,3.674]
# 10 (50, 256, 256, 3)
# >473, dA[0.094,0.142] dB[0.014,0.040] g[6.078,5.081]
# 21 (50, 256, 256, 3)
# 21 (50, 256, 256, 3)
# >474, dA[0.193,0.162] dB[0.008,0.034] g[4.355,3.914]
# 41 (50, 256, 256, 3)
# 10 (50, 256, 256, 3)
# >475, dA[0.126,0.048] dB[0.056,0.085] g[2.986,2.578]
# 25 (50, 256, 256, 3)
# >476, dA[0.059,0.133] dB[0.020,0.010] g[5.950,4.366]
# >477, dA[0.051,0.175] dB[0.012,0.009] g[3.873,2.907]
# 46 (50, 256, 256, 3)
# >478, dA[0.312,0.129] dB[0.012,0.014] g[7.444,6.219]
# 12 (50, 256, 256, 3)
# 45 (50, 256, 256, 3)
# >479, dA[0.200,0.126] dB[0.021,0.015] g[6.517,5.056]
# 40 (50, 256, 256, 3)
# 0 (50, 256, 256, 3)
# >480, dA[0.074,0.141] dB[0.004,0.007] g[5.691,4.202]
# 44 (50, 256, 256, 3)
# >481, dA[0.206,0.120] dB[0.017,0.034] g[3.338,2.677]
# 10 (50, 256, 256, 3)
# 4 (50, 256, 256, 3)
# >482, dA[0.132,0.224] dB[0.014,0.010] g[7.844,5.803]
# >483, dA[0.130,0.092] dB[0.004,0.011] g[4.699,3.939]
# >484, dA[0.145,0.130] dB[0.104,0.075] g[3.148,2.728]
# 49 (50, 256, 256, 3)
# >485, dA[0.158,0.137] dB[0.065,0.033] g[6.430,5.057]
# 28 (50, 256, 256, 3)
# 43 (50, 256, 256, 3)
# >486, dA[0.254,0.141] dB[0.059,0.084] g[4.020,3.931]
# >487, dA[0.075,0.204] dB[0.017,0.020] g[6.252,4.918]
# >488, dA[0.100,0.094] dB[0.026,0.007] g[7.548,6.587]
# 44 (50, 256, 256, 3)
# 1 (50, 256, 256, 3)
# >489, dA[0.250,0.074] dB[0.017,0.014] g[6.723,5.203]
# 36 (50, 256, 256, 3)
# 37 (50, 256, 256, 3)
# >490, dA[0.105,0.211] dB[0.032,0.014] g[2.938,2.362]
# 16 (50, 256, 256, 3)
# 35 (50, 256, 256, 3)
# >491, dA[0.040,0.099] dB[0.051,0.099] g[3.299,3.407]
# 15 (50, 256, 256, 3)
# 35 (50, 256, 256, 3)
# >492, dA[0.124,0.093] dB[0.013,0.039] g[7.087,5.519]
# 17 (50, 256, 256, 3)
# 3 (50, 256, 256, 3)
# >493, dA[0.243,0.152] dB[0.076,0.056] g[7.720,5.961]
# 37 (50, 256, 256, 3)
# >494, dA[0.066,1.278] dB[0.008,0.050] g[4.041,2.981]
# 42 (50, 256, 256, 3)
# 0 (50, 256, 256, 3)
# >495, dA[0.082,0.209] dB[0.112,0.068] g[5.866,4.340]
# >496, dA[0.119,0.120] dB[0.017,0.049] g[6.180,4.816]
# 20 (50, 256, 256, 3)
# 20 (50, 256, 256, 3)
# >497, dA[0.207,0.094] dB[0.064,0.026] g[3.926,2.975]
# 5 (50, 256, 256, 3)
# >498, dA[0.093,0.136] dB[0.117,0.161] g[3.913,3.683]
# 38 (50, 256, 256, 3)
# >499, dA[0.096,0.092] dB[0.007,0.016] g[7.351,5.389]
# 6 (50, 256, 256, 3)
# >500, dA[0.136,0.222] dB[0.002,0.013] g[7.064,4.918]

# %% [markdown]
# # **Task 3**: Write a test function to generate fake images for the test set
# ### Create Day->Night, Night->Day. versions separately
# ### Visualize some images. What parameters would you change to improve?
# Hint: Use the format of the train function to create the test function.

# %%
#Define a test function to generate day to night images
import matplotlib.pyplot as plt
def test(g_model_AtoB, g_model_BtoA, 
         c_model_AtoB, c_model_BtoA,
         trainA, trainB):
###################START CODE HERE#############################
  X_realA, _ = generate_real_samples(trainA, 1, 16)
  X_fakeA, _ = generate_fake_samples(g_model_AtoB, X_realA, 16)
  
  X_realB, _ = generate_real_samples(trainB, 1, 16)
  X_fakeB, _ = generate_fake_samples(g_model_BtoA, X_realB, 16)
###############################################################    
    ########First Day to night transformation
  print('Original Day Image is=\n')
  plt.imshow(np.squeeze(X_realA))
  plt.show()
  print('Fake Night image is=\n')
  plt.imshow(np.squeeze(X_fakeA))
  plt.show()
  #############Next Night to Day transformation
  print('Original Night Image is=\n')
  plt.imshow(np.squeeze(X_realB))
  plt.show()
  print('Fake Day image is=\n')
  plt.imshow(np.squeeze(X_fakeB))
  plt.show()

# %%
##Call the test function here test(.....)
#########START CODE HERE###############################
test(gen_a2b, gen_b2a, 
     c_model_AtoB, c_model_BtoA,
     trainA, trainB)
########################################################
# Out:
# Original Day Image is=
# Fake Night image is=
# Original Night Image is=
# Fake Day image is=

# %% [markdown]
#  # Notice a Banding around edges for the nighttime images. What paremeter would you change to reduce this banding?
#
#  I think that changing the discriminator patch size might help reduce this banding. Specifically increasing the field of view of the patches which might result in the discriminator learning more information. That in turn would give a positive feedback and force generator to make better 'fake' images.

# %% [markdown]
# # **Task 4**: Write a function to generate a full cycle Day->night->Day
# [Hint]: Use the template in the train function to start with Day image and plot the cyclic day image generated.
#
# # Write a function to quantify the error and similarity between the cycle generated image and original image (Day vs Generated Day)
# [Hint]: Find mse and structural similarity between real and fake images to gauge the quality of cycleGAN.

# %%
#Function to compute similarity in Cycle images
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import mean_squared_error

def similarity_real_fake(real,fake):
  ###################Start Code Here##############################
  mse_cycle = mean_squared_error(real, fake)
  ssim_cycle = ssim(real, fake, multichannel=True, 
                    gaussian_weights=True, sigma=1.5)
  print('MSE= ', mse_cycle)
  print('SSIM= ', ssim_cycle)
  ################################################################

# %%
def test_Cycle(g_model_AtoB, g_model_BtoA, c_model_AtoB,
               c_model_BtoA, trainA,trainB):

  # write this function to call the similarity_real_fake function above 
  # and print it under each real->Generated image pair
  ##############START CODE HERE######################################
  # define training parameters
  n_epochs, n_batch = 1, 1

  # set the patch size for discriminator
  n_patch = 32

  n_steps = 50

  for i in range(n_steps):
    # get real samples
    X_realA, y_realA = generate_real_samples(trainA, n_batch, n_patch)
    X_realB, y_realB = generate_real_samples(trainB, n_batch, n_patch)

    # generate fake samples
    X_fakeA, y_fakeA = generate_fake_samples(g_model_BtoA, X_realB, n_patch)
    X_fakeB, y_fakeB = generate_fake_samples(g_model_AtoB, X_realA, n_patch)

    # get fake/real samples
    X_fakeAA, y_fakeAA = generate_fake_samples(g_model_BtoA, X_fakeB, n_patch)
    X_fakeBB, y_fakeBB = generate_fake_samples(g_model_AtoB, X_fakeA, n_patch)
  ###################################################################
  # day to night transform
  realA = np.squeeze(X_realA)
  fakeA = np.squeeze(X_fakeAA)
  print('Original Day Image: \n')
  plt.imshow(realA)
  plt.show()
  print('Fake Day Image: \n')
  plt.imshow(fakeA)
  plt.show()

  similarity_real_fake(realA, fakeA)

  # night to day transform
  realB = np.squeeze(X_realB)
  fakeB = np.squeeze(X_fakeBB)
  print('Orginal Night Image: \n')
  plt.imshow(realB)
  plt.show()
  print('Fake Night Image: \n')
  plt.imshow(fakeB)
  plt.show()

  similarity_real_fake(realB, fakeB)

# %%
# Call the function test_Cycle(....)
test_Cycle(gen_a2b, gen_b2a, 
           c_model_AtoB, c_model_BtoA,
           trainA, trainB)
# Out:
# Original Day Image:
# Fake Day Image:
# MSE=  0.010374131174100664
# SSIM=  0.6563230998131981
# Orginal Night Image:
# /usr/local/lib/python3.6/dist-packages/skimage/metrics/_structural_similarity.py:108: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   im2[..., ch], **args)
# Fake Night Image:
# MSE=  0.041950696955919575
# SSIM=  0.5451213265463123

# %% [markdown]
# # Comment on which domain transformation is better quality and some steps to improve performance.
#
# I tried changing the n_patch and n_steps, overall the day to day transformation seems to do better than night to night. Also increasing patch size to 64 did not give signficantly better results than patch size of 32.
#
# To improve performance I would train on the full dataset or at least train on the full night dataset. It seems like the features on night pictures are harder to learn which leads to worse outcomes for that domain.
